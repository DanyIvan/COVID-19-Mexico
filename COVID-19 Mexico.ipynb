# %% [markdown]
# # Analyzing COVID-19 data in Mexico

# %% [markdown]
# In this notebook I will analyze a data set with COVID-19 data in Mexico using the CRISP-DM process. This data set is updated daily and can be found in the Mexico City government [webpage](https://datos.cdmx.gob.mx/explore/dataset/casos-asociados-a-covid-19/). I downloaded the data from this page on May 1st 2020, and I compressed it using 'gzip' method from pandas.
#
# ## Business and Data Understanding
#
# Let's begin by taking a look a the data.

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
english_cols = ['date_update','origin','sector','medical_unit_entity','sex','birth_entity',
'residency_entity','municipality_of_residence','patient_type','admission_date',
'date_symptoms','death_date','intubed','pneumonia','age','nationality',
'pregnancy','speaks_indigenous_language','diabetes','copd','asthma',
'immunosuppression','hypertension','other_complication','cardiovascular',
'obesity','chronic_kidney','tobacco','another_case','outcome','migrant',
'country_nationality','country_of_origin','intensive_care_unit','age_range',
'register_id','death','hospitalized']
covid_data = pd.read_csv('covid-19-mex.csv', skiprows=1, names = english_cols, compression='gzip')

# %%
covid_data.head()
# Out:
#   date_update          origin sector medical_unit_entity    sex  \
# 0  2020-04-30  FUERA DE USMER    SSA    CIUDAD DE MÉXICO  MUJER
# 1  2020-04-30  FUERA DE USMER   IMSS    CIUDAD DE MÉXICO  MUJER
# 2  2020-04-30           USMER    SSA             MORELOS  MUJER
# 3  2020-04-30           USMER   IMSS            CAMPECHE  MUJER
# 4  2020-04-30  FUERA DE USMER    SSA    CIUDAD DE MÉXICO  MUJER
#
#        birth_entity  residency_entity municipality_of_residence  \
# 0  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO                Iztapalapa
# 1  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO                Iztapalapa
# 2           MORELOS           MORELOS                   Tláhuac
# 3           TABASCO           TABASCO         Gustavo A. Madero
# 4  CIUDAD DE MÉXICO  CIUDAD DE MÉXICO       Venustiano Carranza
#
#     patient_type admission_date  ...     another_case                 outcome  \
# 0    AMBULATORIO     2020-04-07  ...               SI  No positivo SARS-CoV-2
# 1    AMBULATORIO     2020-04-12  ...  NO ESPECIFICADO  No positivo SARS-CoV-2
# 2    AMBULATORIO     2020-04-02  ...               NO  No positivo SARS-CoV-2
# 3  HOSPITALIZADO     2020-04-15  ...  NO ESPECIFICADO  No positivo SARS-CoV-2
# 4    AMBULATORIO     2020-04-28  ...               NO  No positivo SARS-CoV-2
#
#            migrant country_nationality  country_of_origin intensive_care_unit  \
# 0  NO ESPECIFICADO              México                 99           NO APLICA
# 1  NO ESPECIFICADO              México                 99           NO APLICA
# 2  NO ESPECIFICADO              México                 99           NO APLICA
# 3  NO ESPECIFICADO              México                 99                  NO
# 4  NO ESPECIFICADO              México                 99           NO APLICA
#
#   age_range register_id death hospitalized
# 0     41-50      091c2e   NaN          NaN
# 1     06-15      14bbc1   NaN          NaN
# 2     21-30      1840b3   NaN          NaN
# 3     21-30      118206   NaN          1.0
# 4     41-50      1221b8   NaN          NaN
#
# [5 rows x 38 columns]

# %%
covid_data.shape
# Out:
# (87372, 38)

# %%
covid_data.describe(include = 'all')
# Out:
#        date_update          origin sector medical_unit_entity     sex  \
# count        87372           87372  87372               87372   87372
# unique           1               2     13                  32       2
# top     2020-04-30  FUERA DE USMER    SSA    CIUDAD DE MÉXICO  HOMBRE
# freq         87372           54009  47450               21795   44124
# mean           NaN             NaN    NaN                 NaN     NaN
# std            NaN             NaN    NaN                 NaN     NaN
# min            NaN             NaN    NaN                 NaN     NaN
# 25%            NaN             NaN    NaN                 NaN     NaN
# 50%            NaN             NaN    NaN                 NaN     NaN
# 75%            NaN             NaN    NaN                 NaN     NaN
# max            NaN             NaN    NaN                 NaN     NaN
#
#             birth_entity  residency_entity municipality_of_residence  \
# count              87372             87372                     38402
# unique                33                32                        16
# top     CIUDAD DE MÉXICO  CIUDAD DE MÉXICO         Gustavo A. Madero
# freq               19600             18703                      4332
# mean                 NaN               NaN                       NaN
# std                  NaN               NaN                       NaN
# min                  NaN               NaN                       NaN
# 25%                  NaN               NaN                       NaN
# 50%                  NaN               NaN                       NaN
# 75%                  NaN               NaN                       NaN
# max                  NaN               NaN                       NaN
#
#        patient_type admission_date  ...     another_case  \
# count         87372          87372  ...            87372
# unique            2            121  ...                3
# top     AMBULATORIO     2020-04-28  ...  NO ESPECIFICADO
# freq          64207           4120  ...            32806
# mean            NaN            NaN  ...              NaN
# std             NaN            NaN  ...              NaN
# min             NaN            NaN  ...              NaN
# 25%             NaN            NaN  ...              NaN
# 50%             NaN            NaN  ...              NaN
# 75%             NaN            NaN  ...              NaN
# max             NaN            NaN  ...              NaN
#
#                        outcome          migrant country_nationality  \
# count                    87372            87372               87372
# unique                       3                3                  71
# top     No positivo SARS-CoV-2  NO ESPECIFICADO              México
# freq                     52628            86920               86193
# mean                       NaN              NaN                 NaN
# std                        NaN              NaN                 NaN
# min                        NaN              NaN                 NaN
# 25%                        NaN              NaN                 NaN
# 50%                        NaN              NaN                 NaN
# 75%                        NaN              NaN                 NaN
# max                        NaN              NaN                 NaN
#
#         country_of_origin intensive_care_unit age_range register_id   death  \
# count               87372               87372     87363       87372  3077.0
# unique                 29                   4        11       87372     NaN
# top                    99           NO APLICA     31-40      06a3e9     NaN
# freq                87187               64207     21072           1     NaN
# mean                  NaN                 NaN       NaN         NaN     1.0
# std                   NaN                 NaN       NaN         NaN     0.0
# min                   NaN                 NaN       NaN         NaN     1.0
# 25%                   NaN                 NaN       NaN         NaN     1.0
# 50%                   NaN                 NaN       NaN         NaN     1.0
# 75%                   NaN                 NaN       NaN         NaN     1.0
# max                   NaN                 NaN       NaN         NaN     1.0
#
#        hospitalized
# count       23165.0
# unique          NaN
# top             NaN
# freq            NaN
# mean            1.0
# std             0.0
# min             1.0
# 25%             1.0
# 50%             1.0
# 75%             1.0
# max             1.0
#
# [11 rows x 38 columns]

# %%
#explore values of data
print('columns unique values')
for col in covid_data.columns:
    print(col, covid_data[col].unique())
# Out:
# columns unique values
# date_update ['2020-04-30']
# origin ['FUERA DE USMER' 'USMER']
# sector ['SSA' 'IMSS' 'ISSSTE' 'ESTATAL' 'PRIVADA' 'NO ESPECIFICADO' 'PEMEX'
#  'SEDEMA' 'UNIVERSITARIO' 'SEMAR' 'MUNICIPAL' 'DIF' 'CRUZ ROJA']
# medical_unit_entity ['CIUDAD DE MÉXICO' 'MORELOS' 'CAMPECHE' 'MÉXICO' 'GUERRERO' 'CHIHUAHUA'
#  'JALISCO' 'VERACRUZ DE IGNACIO DE LA LLAVE' 'SONORA'
#  'MICHOACÁN DE OCAMPO' 'BAJA CALIFORNIA' 'COAHUILA DE ZARAGOZA' 'YUCATÁN'
#  'SAN LUIS POTOSÍ' 'TAMAULIPAS' 'BAJA CALIFORNIA SUR' 'OAXACA' 'TABASCO'
#  'SINALOA' 'TLAXCALA' 'HIDALGO' 'GUANAJUATO' 'QUINTANA ROO' 'PUEBLA'
#  'NAYARIT' 'AGUASCALIENTES' 'NUEVO LEÓN' 'QUERÉTARO' 'CHIAPAS' 'ZACATECAS'
#  'COLIMA' 'DURANGO']
# sex ['MUJER' 'HOMBRE']
# birth_entity ['CIUDAD DE MÉXICO' 'MORELOS' 'TABASCO' 'MÉXICO' 'GUERRERO' 'CHIHUAHUA'
#  'JALISCO' 'VERACRUZ DE IGNACIO DE LA LLAVE' 'NAYARIT' 'HIDALGO'
#  'NO ESPECIFICADO' 'COAHUILA DE ZARAGOZA' 'YUCATÁN' 'SAN LUIS POTOSÍ'
#  'TAMAULIPAS' 'BAJA CALIFORNIA SUR' 'BAJA CALIFORNIA'
#  'MICHOACÁN DE OCAMPO' 'OAXACA' 'TLAXCALA' 'PUEBLA' 'GUANAJUATO' 'SINALOA'
#  'AGUASCALIENTES' 'CHIAPAS' 'NUEVO LEÓN' 'QUINTANA ROO' 'CAMPECHE'
#  'ZACATECAS' 'QUERÉTARO' 'DURANGO' 'SONORA' 'COLIMA']
# residency_entity ['CIUDAD DE MÉXICO' 'MORELOS' 'TABASCO' 'MÉXICO' 'GUERRERO' 'CHIHUAHUA'
#  'JALISCO' 'VERACRUZ DE IGNACIO DE LA LLAVE' 'SONORA' 'BAJA CALIFORNIA'
#  'COAHUILA DE ZARAGOZA' 'YUCATÁN' 'SAN LUIS POTOSÍ' 'TAMAULIPAS'
#  'BAJA CALIFORNIA SUR' 'OAXACA' 'MICHOACÁN DE OCAMPO' 'SINALOA' 'TLAXCALA'
#  'HIDALGO' 'GUANAJUATO' 'QUINTANA ROO' 'PUEBLA' 'NAYARIT' 'AGUASCALIENTES'
#  'NUEVO LEÓN' 'CAMPECHE' 'QUERÉTARO' 'CHIAPAS' 'ZACATECAS' 'COLIMA'
#  'DURANGO']
# municipality_of_residence ['Iztapalapa' 'Tláhuac' 'Gustavo A. Madero' 'Venustiano Carranza'
#  'Cuauhtémoc' 'Iztacalco' nan 'Benito Juárez' 'Azcapotzalco' 'Xochimilco'
#  'Coyoacán' 'Álvaro Obregón' 'Tlalpan' 'Cuajimalpa de Morelos'
#  'La Magdalena Contreras' 'Milpa Alta' 'Miguel Hidalgo']
# patient_type ['AMBULATORIO' 'HOSPITALIZADO']
# admission_date ['2020-04-07' '2020-04-12' '2020-04-02' '2020-04-15' '2020-04-28'
#  '2020-04-24' '2020-04-14' '2020-04-10' '2020-04-29' '2020-04-17'
#  '2020-03-12' '2020-03-17' '2020-03-28' '2020-04-20' '2020-03-22'
#  '2020-04-26' '2020-03-24' '2020-04-11' '2020-04-13' '2020-04-09'
#  '2020-04-21' '2020-03-18' '2020-04-23' '2020-04-25' '2020-03-29'
#  '2020-04-08' '2020-03-26' '2020-03-31' '2020-04-04' '2020-04-19'
#  '2020-04-22' '2020-04-03' '2020-03-30' '2020-04-16' '2020-04-06'
#  '2020-03-27' '2020-03-21' '2020-03-23' '2020-04-30' '2020-03-11'
#  '2020-04-01' '2020-04-18' '2020-02-25' '2020-03-25' '2020-04-27'
#  '2020-04-05' '2020-02-10' '2020-03-19' '2020-01-24' '2020-01-21'
#  '2020-03-16' '2020-03-14' '2020-02-19' '2020-03-02' '2020-01-30'
#  '2020-02-18' '2020-03-13' '2020-02-05' '2020-01-14' '2020-03-09'
#  '2020-03-15' '2020-02-28' '2020-01-28' '2020-03-10' '2020-01-20'
#  '2020-03-20' '2020-01-09' '2020-03-08' '2020-02-17' '2020-01-19'
#  '2020-02-27' '2020-01-22' '2020-03-03' '2020-02-12' '2020-01-10'
#  '2020-02-15' '2020-02-24' '2020-03-04' '2020-02-02' '2020-01-15'
#  '2020-02-13' '2020-02-26' '2020-02-11' '2020-01-16' '2020-01-02'
#  '2020-01-13' '2020-02-03' '2020-01-07' '2020-03-05' '2020-02-20'
#  '2020-01-27' '2020-01-23' '2020-01-06' '2020-02-14' '2020-02-07'
#  '2020-02-04' '2020-01-25' '2020-02-08' '2020-01-17' '2020-01-12'
#  '2020-01-18' '2020-03-01' '2020-03-06' '2020-01-03' '2020-02-16'
#  '2020-02-06' '2020-01-31' '2020-01-08' '2020-01-26' '2020-02-22'
#  '2020-02-23' '2020-02-09' '2020-01-05' '2020-03-07' '2020-02-01'
#  '2020-02-29' '2020-02-21' '2020-01-29' '2020-01-11' '2020-01-01'
#  '2020-01-04']
# date_symptoms ['2020-04-03' '2020-04-10' '2020-03-31' '2020-04-15' '2020-04-26'
#  '2020-04-21' '2020-04-08' '2020-04-04' '2020-04-14' '2020-04-28'
#  '2020-04-01' '2020-04-16' '2020-03-02' '2020-03-17' '2020-03-24'
#  '2020-04-17' '2020-03-20' '2020-04-24' '2020-04-11' '2020-04-06'
#  '2020-04-18' '2020-04-09' '2020-04-19' '2020-04-02' '2020-03-14'
#  '2020-04-23' '2020-03-29' '2020-04-07' '2020-03-16' '2020-04-22'
#  '2020-03-23' '2020-03-30' '2020-04-13' '2020-03-28' '2020-04-27'
#  '2020-04-25' '2020-04-12' '2020-03-26' '2020-04-05' '2020-04-29'
#  '2020-03-21' '2020-03-11' '2020-04-30' '2020-03-10' '2020-04-20'
#  '2020-01-24' '2020-03-15' '2020-03-27' '2020-03-13' '2020-03-25'
#  '2020-02-09' '2020-03-18' '2020-01-23' '2020-03-19' '2020-01-19'
#  '2020-03-22' '2020-03-07' '2020-02-16' '2020-02-13' '2020-03-12'
#  '2020-02-28' '2020-01-29' '2020-02-14' '2020-02-04' '2020-01-10'
#  '2020-03-09' '2020-03-08' '2020-03-05' '2020-03-04' '2020-02-27'
#  '2020-01-28' '2020-02-29' '2020-03-01' '2020-03-06' '2020-01-20'
#  '2020-01-07' '2020-01-11' '2020-01-09' '2020-01-15' '2020-01-21'
#  '2020-01-17' '2020-02-25' '2020-01-14' '2020-02-06' '2020-03-03'
#  '2020-01-26' '2020-01-06' '2020-02-22' '2020-01-04' '2020-02-26'
#  '2020-01-08' '2020-02-02' '2020-01-22' '2020-01-12' '2020-01-18'
#  '2020-02-11' '2020-02-24' '2020-02-05' '2020-01-02' '2020-01-13'
#  '2020-02-18' '2020-02-03' '2020-01-30' '2020-02-17' '2020-01-27'
#  '2020-02-12' '2020-02-01' '2020-01-05' '2020-01-25' '2020-02-23'
#  '2020-02-08' '2020-02-07' '2020-02-10' '2020-02-20' '2020-01-03'
#  '2020-02-19' '2020-01-31' '2020-02-21' '2020-02-15' '2020-01-16'
#  '2020-01-01']
# death_date [nan '2020-04-24' '2020-04-16' '2020-04-25' '2020-04-12' '2020-04-02'
#  '2020-04-11' '2020-04-09' '2020-04-01' '2020-04-26' '2020-04-08'
#  '2020-04-19' '2020-04-10' '2020-04-21' '2020-04-15' '2020-04-04'
#  '2020-04-14' '2020-04-22' '2020-04-20' '2020-04-27' '2020-03-27'
#  '2020-04-13' '2020-04-07' '2020-04-28' '2020-04-23' '2020-03-31'
#  '2020-04-06' '2020-03-30' '2020-04-05' '2020-04-29' '2020-04-18'
#  '2020-04-17' '2020-03-24' '2020-03-16' '2020-04-03' '2020-03-26'
#  '2020-03-28' '2020-03-04' '2020-02-23' '2020-03-29' '2020-03-25'
#  '2020-04-30' '2020-03-20' '2020-01-29' '2020-03-18' '2020-03-22'
#  '2020-03-17' '2020-03-23' '2020-02-10' '2020-01-15' '2020-03-19'
#  '2020-03-09']
# intubed ['NO APLICA' 'NO' 'SI' 'NO ESPECIFICADO']
# pneumonia ['NO' 'SI' 'NO ESPECIFICADO']
# age [ 43  13  24  30  41  45   7  71  27  46  21  42  72   8  58  36  80  60
#   37  59  20  33  52  38  29  65  61  47  55  70  64  28  14  40  74  49
#   57  53  79  26  34  39  32  25  19  48  76  82  22  66  69   5  44  63
#   89   0  94  31  68  11  50  23  17  51  35  54   9 101  67  81  75  62
#   56  96  90   2  16  87   3   6  84  73  15  95   4  78  77  85   1  93
#   83  10  91  12  18  86  92  97  88  98  99 100 113 102]
# nationality ['MEXICANA' 'EXTRANJERA']
# pregnancy ['NO' 'SI' 'NO APLICA' 'SE IGNORA']
# speaks_indigenous_language ['NO' 'NO ESPECIFICADO' 'SI']
# diabetes ['NO' 'SI' 'SE IGNORA']
# copd ['NO' 'SI' 'SE IGNORA']
# asthma ['NO' 'SI' 'SE IGNORA']
# immunosuppression ['NO' 'SI' 'SE IGNORA']
# hypertension ['NO' 'SI' 'SE IGNORA']
# other_complication ['NO' 'SI' 'SE IGNORA']
# cardiovascular ['NO' 'SI' 'SE IGNORA']
# obesity ['SI' 'NO' 'SE IGNORA']
# chronic_kidney ['NO' 'SI' 'SE IGNORA']
# tobacco ['NO' 'SI' 'SE IGNORA']
# another_case ['SI' 'NO ESPECIFICADO' 'NO']
# outcome ['No positivo SARS-CoV-2' 'Resultado pendiente' 'Positivo SARS-CoV-2']
# migrant ['NO ESPECIFICADO' 'NO' 'SI']
# country_nationality ['México' 'Trieste' 'Colombia' 'Estados Unidos de América' 'Islandia'
#  'Argentina' 'Guatemala' 'Francia' 'Rusia' 'República de Honduras'
#  'Italia' 'Otro' 'República Dominicana' 'Alemania' 'Belice' 'Perú'
#  'España' 'Principado de MÃ³naco' 'IrÃ¡n' 'Venezuela' 'Irlanda'
#  'Nicaragua' 'Cuba' 'Gran Bretaña (Reino Unido)' 'Chile' 'China' 'Haití'
#  'Macao' 'Japón' 'Canadá' 'El Salvador' 'Paraguay' 'Bolivia' 'Rumania'
#  'India' 'Brasil' 'Ecuador' 'Suiza' 'Suecia' 'Holanda'
#  'RepÃºblica de Mauricio' 'RepÃºblica de PanamÃ¡' 'TurquÃ\xada' 'Polonia'
#  'RepÃºblica de Angola' 'Egipto' 'HungrÃ\xada' 'Ucrania'
#  'RepÃºblica de Corea' 'Israel' 'ArchipiÃ©lago de Svalbard' 'Zona Neutral'
#  'LÃ\xadbano' 'Commonwealth de Dominica' 'Austria' 'Micronesia'
#  'Costa de Marfil' 'RepÃºblica de Costa Rica' 'Australia' 'CamerÃºn'
#  'Portugal' 'PakistÃ¡n' 'Eritrea' 'Grecia' 'Malasia' 'AscensiÃ³n'
#  'Zimbabwe' 'RepÃºblica Oriental del Uruguay' 'Argelia'
#  'Bosnia y Herzegovina' 'Noruega']
# country_of_origin ['99' 'Estados Unidos de América' 'República de Honduras' 'Belice' 'Otro'
#  'Venezuela' 'Nicaragua' 'Colombia' 'El Salvador' 'Haití' 'Cuba'
#  'Guatemala' 'Alemania' 'Japón' 'Egipto' 'Canadá' 'Irlanda' 'España'
#  'Bolivia' 'Chile' 'Italia' 'Ecuador' 'Costa de Marfil' 'China' 'Camerún'
#  'Brasil' 'Eritrea' 'Grecia' 'Perú']
# intensive_care_unit ['NO APLICA' 'NO' 'SI' 'NO ESPECIFICADO']
# age_range ['41-50' '06-15' '21-30' '71-80' '51-60' '31-40' '16-20' '61-70' '81-90'
#  '0-05' '91-100' nan]
# register_id ['091c2e' '14bbc1' '1840b3' ... '026b61' '1a58a7' '1b1bfb']
# death [nan  1.]
# hospitalized [nan  1.]

# %% [markdown]
# From the above, we can see that this data contains medical information from all the people that have been tested for COVID-19 in Mexico. The majority of the columns in this data set are categorical. There is only three numerical columns: age, death and hospitalized. Some columns and rows contain NAN values. However, other columns contain NAN values expressed in strings like 'NO APLICA', 'NO ESPECIFICADO', and 'SE IGNORA', that in english  mean 'NOT APPLY', 'NOT SPECIFIED', and 'IT IS IGNORED'.
#
# It is clear that we will have to do some cleaning, but first let's formulate some interesting questions that could be answered with the data.
#
# ### Business Questions
#
# I would like to understand the following questions with this data:
#
# * 1. __What kind of people are infected with COVID-19 in Mexico?__ To answer this question we will have to look at columns such as sex, age or municipality_residence.
# * 2. __What is related to the severity of COVID 19? Specifically, can we predict whether a person is likely to be intubated, or whether a person will survive the disease?__  To answer this question we will have to look at columns such as intubated, diabetes, asthma etc.
# * 3. __Can we make a prediction for the end of the pandemic in Mexico City from this data?__ To answer this question we will use the data from daily cumulative cases in Mexico City and an epidemic model.
#
# ### Data Preparation
#
# Let's do some cleaning of the data
